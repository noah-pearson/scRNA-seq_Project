# %%
from scipy import io
import pandas as pd
import umap # First time you run this enter pip install umap-learn in your Anaconda Prompt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from sklearn.cluster import KMeans
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

# %%
norm = 'E-GEOD-100911.aggregated_filtered_normalised_counts.mtx'
c = 'E-GEOD-100911.aggregated_filtered_normalised_counts.mtx_cols'
r = 'E-GEOD-100911.aggregated_filtered_normalised_counts.mtx_rows'
cols = []
rows = []
data = io.mmread(norm)
with open(c) as file:
    for line in file:
        cols.append(line.rstrip())

with open(r) as file:
    for line in file:
        rows.append(line.rstrip().split('\t')[0])
arr = data.toarray()

# %%
norm_counts = pd.DataFrame(arr, index = rows, columns = cols)
norm_counts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17432 entries, ENSDARG00000000001 to ENSDARG00000117200
# Columns: 246 entries, SRR5810686 to SRR5810931
# dtypes: float64(246)
# memory usage: 32.8+ MB

# %%
""" This was run to convert the gene transcript IDs to KEGG IDs, since this process took so long
    the result was saved to a csv (geneID.csv) file and this code is not needed anymore. 

from Bio import Entrez
import time
import csv

Entrez.email = "mdpouls1@gmail.com"
geneIDs = []
rowsTest = rows[15000:]
i = 0
while i < len(rowsTest):
    for t in range(3):
        if i < len(rowsTest):
            handle = Entrez.esearch(db="gene", term=rowsTest[i])
            record = Entrez.read(handle)
            if len(record['IdList']) == 1:
                geneIDs.append(record['IdList'][0])
            elif len(record['IdList']) > 1:
                geneIDs.append('multiple')
            else:
                geneIDs.append('NaN')
            handle.close()
            i += 1
    time.sleep(1)

with open('geneID.csv', 'a') as f:
    for gene in geneIDs:
        f.write('{},'.format(gene))
"""

# %%
ID_Data = pd.read_csv('geneID.csv')
IDs = ID_Data.columns

# %%
norm_counts['geneIDs'] = IDs
norm_counts.head(10)
# Out:
#                     SRR5810686  SRR5810687  SRR5810688  SRR5810689  \
# ENSDARG00000000001     0.00000    0.000000    0.000000         0.0
# ENSDARG00000000018     0.00000    0.000000    0.000000         0.0
# ENSDARG00000000019     0.00000    0.000000    0.000000         0.0
# ENSDARG00000000068     0.00000    0.000000    0.000000         0.0
# ENSDARG00000000069   108.11358  477.412380    0.000000         0.0
# ENSDARG00000000086     0.00000    0.000000   21.663803         0.0
# ENSDARG00000000103     0.00000    0.000000    0.000000         0.0
# ENSDARG00000000142     0.00000    0.000000    0.000000         0.0
# ENSDARG00000000151     0.00000   23.762608    0.000000         0.0
# ENSDARG00000000183     0.00000    0.000000    0.000000         0.0
#
#                     SRR5810690  SRR5810691  SRR5810692  SRR5810693  \
# ENSDARG00000000001    3.021731    0.000000      0.0000    0.000000
# ENSDARG00000000018    0.000000   88.754005    423.7024    0.000000
# ENSDARG00000000019    0.000000    0.000000      0.0000    0.000000
# ENSDARG00000000068    0.000000    0.000000      0.0000    0.000000
# ENSDARG00000000069  342.167420  399.198760    169.6043  127.601425
# ENSDARG00000000086    0.000000    0.000000      0.0000  148.062700
# ENSDARG00000000103    0.000000    0.000000      0.0000    0.000000
# ENSDARG00000000142    0.000000    0.000000      0.0000    0.000000
# ENSDARG00000000151    0.000000    0.000000      0.0000    0.000000
# ENSDARG00000000183    0.000000    0.000000      0.0000    0.000000
#
#                     SRR5810694  SRR5810695  ...  SRR5810923  SRR5810924  \
# ENSDARG00000000001    0.000000    0.000000  ...         0.0         0.0
# ENSDARG00000000018  244.993700  480.814330  ...         0.0         0.0
# ENSDARG00000000019    0.000000    0.000000  ...         0.0         0.0
# ENSDARG00000000068    0.000000    0.000000  ...         0.0         0.0
# ENSDARG00000000069    0.000000    0.000000  ...         0.0         0.0
# ENSDARG00000000086    9.043391    2.054422  ...         0.0         0.0
# ENSDARG00000000103  145.516390    0.000000  ...         0.0         0.0
# ENSDARG00000000142    0.000000    0.000000  ...         0.0         0.0
# ENSDARG00000000151   78.102020    4.292985  ...         0.0         0.0
# ENSDARG00000000183    0.000000    0.000000  ...         0.0         0.0
#
#                     SRR5810925  SRR5810926  SRR5810927  SRR5810928  \
# ENSDARG00000000001    0.000000    0.000000         0.0  3123.14040
# ENSDARG00000000018   53.839350   85.774960         0.0     0.00000
# ENSDARG00000000019    0.000000    0.000000         0.0   211.69173
# ENSDARG00000000068    0.000000    0.000000         0.0     0.00000
# ENSDARG00000000069    0.000000    0.000000         0.0     0.00000
# ENSDARG00000000086   21.067574    0.000000         0.0     0.00000
# ENSDARG00000000103    7.802805   75.422806         0.0     0.00000
# ENSDARG00000000142    0.000000    0.000000         0.0     0.00000
# ENSDARG00000000151   91.292816  125.704680         0.0     0.00000
# ENSDARG00000000183    0.000000    0.000000         0.0     0.00000
#
#                     SRR5810929  SRR5810930  SRR5810931  geneIDs
# ENSDARG00000000001     0.00000    0.000000    0.000000   368418
# ENSDARG00000000018     0.00000    0.000000  612.748800    64604
# ENSDARG00000000019     0.00000  168.698530    0.000000   368425
# ENSDARG00000000068     0.00000    0.860707    0.000000   327272
# ENSDARG00000000069     0.00000    0.000000    1.214048    58093
# ENSDARG00000000086     0.00000    0.000000    0.000000   368504
# ENSDARG00000000103   164.37566    0.000000   65.006750   555454
# ENSDARG00000000142     0.00000    0.000000    0.000000   368645
# ENSDARG00000000151     0.00000   82.627850    3.611486    30670
# ENSDARG00000000183     0.00000    0.000000    0.000000   407634
#
# [10 rows x 247 columns]

# %%
norm_counts.to_csv('norm_counts_data.csv')

# %%
with open('dataFile.txt', 'w') as file:
    file.write(' '.join(norm_counts['geneIDs'].to_list()))

# %%
annotationData = pd.read_table('uniprotData.tab')

# %%
annotationData = annotationData.rename(columns={"yourlist:M20210331A94466D2655679D1FD8953E075198DA81B3BDFU": "Ids"})

# %%
annotationData = annotationData.drop("yourlist:M20210331A94466D2655679D1FD8953E075198DA81B3B2BO", axis=1)

# %%
annotationData.head()
# Out:
#       Ids   Entry    Entry name      Status  \
# 0  368418  Q90X48   S35A5_DANRE    reviewed
# 1   64604  Q90X44    NRF1_DANRE    reviewed
# 2  368425  Q7ZUF3  Q7ZUF3_DANRE  unreviewed
# 3  327272  Q6P2U7  Q6P2U7_DANRE  unreviewed
# 4  327272  Q7ZVX1  Q7ZVX1_DANRE  unreviewed
#
#                                        Protein names  \
# 0  Probable UDP-sugar transporter protein SLC35A5...
# 1  Nuclear respiratory factor 1 (Nrf-1) (Not real...
# 2  Ube2h protein (Ubiquitin-conjugating enzyme E2...
# 3     Na(+)/H(+) exchange regulatory cofactor NHE-RF
# 4     Na(+)/H(+) exchange regulatory cofactor NHE-RF
#
#                       Gene names                                     Organism  \
# 0  slc35a5 si:bZ20I5.1 zgc:66231  Danio rerio (Zebrafish) (Brachydanio rerio)
# 1                           nrf1  Danio rerio (Zebrafish) (Brachydanio rerio)
# 2                          ube2h  Danio rerio (Zebrafish) (Brachydanio rerio)
# 3    slc9a3r1a slc9a3r1 slc9a3r2  Danio rerio (Zebrafish) (Brachydanio rerio)
# 4    slc9a3r1a slc9a3r1 slc9a3r2  Danio rerio (Zebrafish) (Brachydanio rerio)
#
#    Length Pathway                                      Function [CC]  \
# 0     440     NaN                                                NaN
# 1     514     NaN  FUNCTION: Probable transcription factor that i...
# 2     183     NaN                                                NaN
# 3     384     NaN  FUNCTION: Scaffold protein that connects plasm...
# 4     386     NaN  FUNCTION: Scaffold protein that connects plasm...
#
#   Tissue specificity                                Developmental stage  \
# 0                NaN                                                NaN
# 1                NaN  DEVELOPMENTAL STAGE: Expressed in the developi...
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
#
#                   Gene ontology (biological process)  \
# 0                carbohydrate transport [GO:0008643]
# 1  cellular response to cold [GO:0070417]; multic...
# 2  protein polyubiquitination [GO:0000209]; ubiqu...
# 3  otic vesicle development [GO:0071599]; protein...
# 4  otic vesicle development [GO:0071599]; protein...
#
#                                    Gene ontology IDs Cross-reference (KEGG)  \
# 0     GO:0005794; GO:0008643; GO:0015165; GO:0030173            dre:368418;
# 1  GO:0000978; GO:0001046; GO:0001895; GO:0003407...             dre:64604;
# 2  GO:0000209; GO:0005524; GO:0005634; GO:0006511...            dre:368425;
# 3  GO:0001726; GO:0005102; GO:0005902; GO:0006612...            dre:327272;
# 4  GO:0001726; GO:0005102; GO:0005902; GO:0006612...            dre:327272;
#
#    Annotation                                           Keywords
# 0  2 out of 5  Glycoprotein;Membrane;Reference proteome;Sugar...
# 1  5 out of 5  Activator;Alternative splicing;DNA-binding;Dev...
# 2  2 out of 5  ATP-binding;Nucleotide-binding;Proteomics iden...
# 3  4 out of 5  Cell projection;Membrane;Proteomics identifica...
# 4  4 out of 5                           Cell projection;Membrane

# %% [markdown]
# # UMAP Reduction:
#
# See the UMAP Documentation page for details. The module import cell at the top of this notebook has instructions for downloading the scikit learn plug-in for UMAP.
#
# NOTE This is a first pass - I'm not super sure it is ready to go. Next steps
#
# 1 We need to cluster the data and assign tags to the data points
#
# 2 Add a third dimension to the UMAP reduction
#
# 3 Plot data in altair to allow interaction
#
# 4 Add interaction steps, tags, whatever else we're doing!

# %%
norm_counts_temp = norm_counts
norm_counts_temp = norm_counts_temp.drop(['geneIDs'],axis=1).transpose()
norm_vals = norm_counts_temp.values

# %%
norm_vals_scaled = StandardScaler().fit_transform(norm_vals)

# %%
UMAP_reducer = umap.UMAP()
reduced_genes = UMAP_reducer.fit_transform(norm_vals_scaled)
print('Done')
# Out:
# Done

# %%
plt.scatter(reduced_genes[:,0],reduced_genes[:,1])
plt.gca().set_aspect('equal','datalim')
plt.title('UMAP projection of Zebra Fish genes, unclustered')
plt.show;

# %%
X = norm_vals_scaled
# PCA
pca_mod = PCA(n_components = 7)
data_pca = pca_mod.fit_transform(X)
PCs =pca_mod.components_
PCs.shape
# Out:
# (7, 17432)

# %%
UMAP_mod = umap.UMAP(n_neighbors = 7, min_dist = 0.2, n_components = 3).fit_transform(X)

# %%
# K means
y_pred = KMeans(n_clusters=7, max_iter=5).fit_predict(X)

# %%
# colors
from matplotlib.colors import ListedColormap
colors = ListedColormap(sns.color_palette('bright', 7).as_hex())
# plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(UMAP_mod[:, 0], UMAP_mod[:, 1],zs= UMAP_mod[:, 2], c=y_pred, cmap= colors, s=20)
ax.set_xlabel('Dimension 1')
ax.set_ylabel('Dimension 2')
ax.set_zlabel('Dimension 3')
plt.show()

# %%
plt.scatter(UMAP_mod[:,0],UMAP_mod[:,1], c = y_pred, cmap = colors, s=15)
plt.gca().set_aspect('equal','datalim')
plt.title('UMAP projection of Zebra Fish genes, unclustered')
plt.show;

# %% [markdown]
# ## Visualization:
# **Overview**
#  - The 'base' plot is the 2-D UMAP plot plotted using Altair.
#  - A user can then select a region-of-interest to create the breakout histogram plots of predominate gene ontology

# %%
import altair as alt

# %% [markdown]
# ### Create visualization dataframe:
# **Overview** by creating a dataframe with the reduced dimension data and add in additional properties as necessary (i.e. cluster number, ontology, etc.)
#
# **To-do:**
#  - Add cluster IDs
#  - Add gene ontologies
#  - Add primary genes?

# %%
# Create 'base' dataframe:
column_names = ["UMAP x","UMAP y"]
vis_data = pd.DataFrame(reduced_genes, columns = column_names)

# Add clusters:
vis_data["Clusters"] = y_pred

vis_data.head()
# Out:
#       UMAP x    UMAP y  Clusters
# 0  10.581582 -0.733993         5
# 1  10.529500 -0.941971         5
# 2  10.731592 -2.349675         5
# 3  11.528299 -0.843344         5
# 4  13.853799 -1.675312         4

# %% [markdown]
# ### Create 'master' plot
# **TODO**
#  - Add cluster colors
#  - Add IDs when hovering?
#  - Add ROI selection

# %%
ROI = alt.selection_interval()

scatter = alt.Chart(vis_data).mark_point().encode(
    alt.X('UMAP x',
          scale=alt.Scale(zero=False)
         ),
    alt.Y('UMAP y',
          scale=alt.Scale(zero=False)
         ),
    color = 'Clusters'
    ).add_selection(ROI)

# Show chart for development purpose:
scatter
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Create histogram plot of ontologies:

# %%
# Create the base chart:
hist_base = alt.Chart(vis_data).mark_bar().encode(
    x = 'count()',
    y = 'Clusters',
    color = 'Clusters'
).properties(
    width = 500,
    height = 200
).transform_filter(
    ROI
)

# Filter by interaction:
# hist = hist_base.encode()


# Display for dev purposes:
scatter | hist_base
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ### Display tool!
# **This is where our interaction is!**

# %%
scatter & hist
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ## Main Dataset

# %%
# unpublished data from cell ranger pipeline
# testis1
t1data = io.mmread('15756X3/matrix.mtx.gz')
t1arr = t1data.toarray()
t1col = pd.read_csv('15756X3/barcodes.tsv.gz', compression = 'gzip', header=None, sep = '\t')
t1row = pd.read_csv('15756X3/features.tsv.gz', compression = 'gzip', header=None,sep = '\t')
t1row = t1row[[1]]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-038834822d80> in <module>
#       1 # unpublished data from cell ranger pipeline
#       2 # testis1
# ----> 3 t1data = io.mmread('15756X3/matrix.mtx.gz')
#       4 t1arr = t1data.toarray()
#       5 t1col = pd.read_csv('15756X3/barcodes.tsv.gz', compression = 'gzip', header=None, sep = '\t')
#
# ~\Anaconda3\lib\site-packages\scipy\io\mmio.py in mmread(source)
#      70         Matrix Market file.
#      71     """
# ---> 72     return MMFile().read(source)
#      73
#      74 # -----------------------------------------------------------------------------
#
# ~\Anaconda3\lib\site-packages\scipy\io\mmio.py in read(self, source)
#     418             Matrix Market file.
#     419         """
# --> 420         stream, close_it = self._open(source)
#     421
#     422         try:
#
# ~\Anaconda3\lib\site-packages\scipy\io\mmio.py in _open(filespec, mode)
#     315             if filespec.endswith('.gz'):
#     316                 import gzip
# --> 317                 stream = gzip.open(filespec, mode)
#     318             elif filespec.endswith('.bz2'):
#     319                 import bz2
#
# ~\Anaconda3\lib\gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      56     gz_mode = mode.replace("t", "")
#      57     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      60         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# ~\Anaconda3\lib\gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     171             mode += 'b'
#     172         if fileobj is None:
# --> 173             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     174         if filename is None:
#     175             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '15756X3/matrix.mtx.gz'

# %%
t1_counts = pd.DataFrame(t1arr, index = t1row, columns = t1col)
t1_counts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32520 entries, ('ptpn12',) to ('CABZ01109058.1',)
# Columns: 8627 entries, ('AAACCTGAGCTAGCCC-1',) to ('TTTGTCATCTGCTGCT-1',)
# dtypes: int64(8627)
# memory usage: 2.1+ GB
